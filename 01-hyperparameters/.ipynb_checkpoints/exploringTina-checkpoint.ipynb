# %%
import cv2
import json
from matplotlib import pyplot as plt
import numpy as np
import os
import random


# import a lot of things from keras:
# sequential model
from keras.models import Sequential

# layers
from keras.layers import Input, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, RandomFlip, RandomRotation, RandomContrast, RandomBrightness

# loss function
from keras.metrics import categorical_crossentropy

# callback functions
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

# convert data to categorial vector representation
from keras.utils import to_categorical

# nice progress bar for loading data
from tqdm.notebook import tqdm

# helper function for train/test split
from sklearn.model_selection import train_test_split

# import confusion matrix helper function
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# import pre-trained model
from keras.applications.vgg16 import VGG16

# include only those gestures
CONDITIONS = ['like', 'stop', 'two_up']

# image size
# IMG_SIZE = 64
# SIZE = (IMG_SIZE, IMG_SIZE)

# number of color channels we want to use
# set to 1 to convert to grayscale
# set to 3 to use color images
COLOR_CHANNELS = 1
# Out:
# 2023-06-10 15:11:46.288920: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.1 when it was built against 1.14.0, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "

# %%
IMG_SIZE_EXPLORATION = [32, 64, 128, 256, 320, 448, 512, 600]
# https://pubs.rsna.org/doi/full/10.1148/ryai.2019190015
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8700246/
# https://www.researchgate.net/post/Which_Image_resolution_should_I_use_for_training_for_deep_neural_network

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14752779077319944301
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1836515328
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 10745154580134217698
# physical_device_desc: "device: 0, name: NVIDIA GeForce MX130, pci bus id: 0000:01:00.0, compute capability: 5.0"
# xla_global_id: 416903419
# ]
# 2023-06-10 15:12:14.389631: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 15:12:14.446582: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 15:12:14.446885: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 15:12:14.447047: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2048] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 5.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2023-06-10 15:12:14.529941: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 15:12:14.530280: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 15:12:14.530518: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 15:12:14.530712: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /device:GPU:0 with 1751 MB memory:  -> device: 0, name: NVIDIA GeForce MX130, pci bus id: 0000:01:00.0, compute capability: 5.0

# %%
annotations = dict()

#PATH = '/media/martinaemmert/561F8ECA05FBCAB1/Week6/gesture_dataset_sample'
PATH = '../../gesture_dataset_sample'
for condition in CONDITIONS:
    with open(f'{PATH}/_annotations/{condition}.json') as f:
        annotations[condition] = json.load(f)

# %% [markdown]
# hier abhängige funktionen dann

# %%
def preprocess_image(img, size):
    if COLOR_CHANNELS == 1:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_resized = cv2.resize(img, (size, size))
    return img_resized

# %%
def load_data(size):
    images = [] # stores actual image data
    labels = [] # stores labels (as integer - because this is what our network needs)
    label_names = [] # maps label ints to their actual categories so we can understand predictions later

    # loop over all conditions
    # loop over all files in the condition's directory
    # read the image and corresponding annotation
    # crop image to the region of interest
    # preprocess image
    # store preprocessed image and label in corresponding lists
    for condition in CONDITIONS:
        for filename in os.listdir(f'{PATH}/{condition}'):
            # extract unique ID from file name
            UID = filename.split('.')[0]
            img = cv2.imread(f'{PATH}/{condition}/{filename}')
            
            # get annotation from the dict we loaded earlier
            try:
                annotation = annotations[condition][UID]
            except Exception as e:
                print(e)
                continue
            
            # iterate over all hands annotated in the image
            for i, bbox in enumerate(annotation['bboxes']):
                # annotated bounding boxes are in the range from 0 to 1
                # therefore we have to scale them to the image size
                x1 = int(bbox[0] * img.shape[1])
                y1 = int(bbox[1] * img.shape[0])
                w = int(bbox[2] * img.shape[1])
                h = int(bbox[3] * img.shape[0])
                x2 = x1 + w
                y2 = y1 + h
                
                # crop image to the bounding box and apply pre-processing
                crop = img[y1:y2, x1:x2]
                preprocessed = preprocess_image(crop, size)
                
                # get the annotated hand's label
                # if we have not seen this label yet, add it to the list of labels
                label = annotation['labels'][i]
                if label not in label_names:
                    label_names.append(label)
                
                label_index = label_names.index(label)
                
                images.append(preprocessed)
                labels.append(label_index)
    return images, labels, label_names

# %%
def prepare_train_test(images, labels, size):
    X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)
    X_train = np.array(X_train).astype('float32')
    X_train = X_train / 255.

    X_test = np.array(X_test).astype('float32')
    X_test = X_test / 255.

    y_train_one_hot = to_categorical(y_train)
    y_test_one_hot = to_categorical(y_test)

    train_label = y_train_one_hot
    test_label = y_test_one_hot

    X_train = X_train.reshape(-1, size, size, COLOR_CHANNELS)
    X_test = X_test.reshape(-1, size, size, COLOR_CHANNELS)
    return X_train, train_label, X_test, test_label

# %%
def build_model(label_names, size):
    # variables for hyperparameters
    batch_size = 8
    epochs = 50

    num_classes = len(label_names)
    activation = 'relu'
    activation_conv = 'LeakyReLU'  # LeakyReLU
    layer_count = 2
    num_neurons = 64

    # define model structure
    # with keras, we can use a model's add() function to add layers to the network one by one
    model = Sequential()

    # data augmentation (this can also be done beforehand - but don't augment the test dataset!)
    #model.add(RandomFlip('horizontal'))
    #model.add(RandomContrast(0.1))
    #model.add(RandomBrightness(0.1))
    #model.add(RandomRotation(0.2))

    # first, we add some convolution layers followed by max pooling
    model.add(Conv2D(64, kernel_size=(9, 9), activation=activation_conv, input_shape=(size, size, COLOR_CHANNELS), padding='same'))
    model.add(MaxPooling2D(pool_size=(4, 4), padding='same'))

    model.add(Conv2D(32, (5, 5), activation=activation_conv, padding='same'))
    model.add(MaxPooling2D(pool_size=(3, 3), padding='same'))

    model.add(Conv2D(32, (3, 3), activation=activation_conv, padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

    # dropout layers can drop part of the data during each epoch - this prevents overfitting
    model.add(Dropout(0.2))

    # after the convolution layers, we have to flatten the data so it can be fed into fully connected layers
    model.add(Flatten())

    # add some fully connected layers ("Dense")
    for i in range(layer_count - 1):
        model.add(Dense(num_neurons, activation=activation))

    model.add(Dense(num_neurons, activation=activation))

    # for classification, the last layer has to use the softmax activation function, which gives us probabilities for each category
    model.add(Dense(num_classes, activation='softmax'))

    # specify loss function, optimizer and evaluation metrics
    # for classification, categorial crossentropy is used as a loss function
    # use the adam optimizer unless you have a good reason not to
    model.compile(loss=categorical_crossentropy, optimizer="adam", metrics=['accuracy'])

    # define callback functions that react to the model's behavior during training
    # in this example, we reduce the learning rate once we get stuck and early stopping
    # to cancel the training if there are no improvements for a certain amount of epochs
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.0001)
    stop_early = EarlyStopping(monitor='val_loss', patience=3)

    # model_params = dict()
    # model_params['batch_size'] = batch_size
    # model_params['epochs'] = epochs
    # model_params['reduce_lr'] = reduce_lr
    # model_params['stop_early'] = stop_early
    return model, batch_size, epochs, reduce_lr, stop_early

# %%
def fit_model(model, batch_size, epochs, reduce_lr, stop_early, X_train, train_labels, X_test, test_labels):
    history = model.fit(
        X_train,
        train_labels,
        batch_size=batch_size,
        epochs=epochs,
        verbose=1,
        validation_data=(X_test, test_labels),
        callbacks=[reduce_lr, stop_early]
    )
    model.summary()
    return history

# %%
def train_with_image_resolution(size):
    images, labels, label_names = load_data(size)
    X_train, train_labels, X_test, test_labels = prepare_train_test(images, labels, size)
    model, batch_size, epochs, reduce_lr, stop_early = build_model(label_names, size)
    return fit_model(model, batch_size, epochs, reduce_lr, stop_early, X_train, train_labels, X_test, test_labels)

# %%
history_for_size = []
#for size in IMG_SIZE_EXPLORATION:
#    history_for_size.append((size, train_with_image_resolution(size)))  
# venv kernel died when iterating over different resolutions

# %%
history_for_size.append((IMG_SIZE_EXPLORATION[0], train_with_image_resolution(IMG_SIZE_EXPLORATION[0])))
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
history_for_size.append((IMG_SIZE_EXPLORATION[1], train_with_image_resolution(IMG_SIZE_EXPLORATION[1])))
# Out:
# Epoch 1/50
# 96/96 [==============================] - 6s 52ms/step - loss: 1.3842 - accuracy: 0.2572 - val_loss: 1.3361 - val_accuracy: 0.2880 - lr: 0.0010
# Epoch 2/50
# 96/96 [==============================] - 5s 52ms/step - loss: 1.3517 - accuracy: 0.3307 - val_loss: 1.2115 - val_accuracy: 0.3927 - lr: 0.0010
# Epoch 3/50
# 96/96 [==============================] - 5s 56ms/step - loss: 1.0741 - accuracy: 0.5354 - val_loss: 0.9141 - val_accuracy: 0.6859 - lr: 0.0010
# Epoch 4/50
# 96/96 [==============================] - 6s 57ms/step - loss: 0.7414 - accuracy: 0.7192 - val_loss: 0.5449 - val_accuracy: 0.8168 - lr: 0.0010
# Epoch 5/50
# 96/96 [==============================] - 6s 61ms/step - loss: 0.5565 - accuracy: 0.8058 - val_loss: 0.3904 - val_accuracy: 0.8482 - lr: 0.0010
# Epoch 6/50
# 96/96 [==============================] - 5s 53ms/step - loss: 0.3934 - accuracy: 0.8688 - val_loss: 0.3725 - val_accuracy: 0.8743 - lr: 0.0010
# Epoch 7/50
# 96/96 [==============================] - 5s 53ms/step - loss: 0.3015 - accuracy: 0.9003 - val_loss: 0.4011 - val_accuracy: 0.8639 - lr: 0.0010
# Epoch 8/50
# 96/96 [==============================] - 5s 53ms/step - loss: 0.2499 - accuracy: 0.9304 - val_loss: 0.3599 - val_accuracy: 0.8639 - lr: 0.0010
# Epoch 9/50
# 96/96 [==============================] - 5s 53ms/step - loss: 0.1997 - accuracy: 0.9278 - val_loss: 0.3158 - val_accuracy: 0.8848 - lr: 0.0010
# Epoch 10/50
# 96/96 [==============================] - 5s 55ms/step - loss: 0.1749 - accuracy: 0.9423 - val_loss: 0.3457 - val_accuracy: 0.8796 - lr: 0.0010
# Epoch 11/50
# 96/96 [==============================] - 6s 58ms/step - loss: 0.1750 - accuracy: 0.9396 - val_loss: 0.2648 - val_accuracy: 0.9005 - lr: 0.0010
# Epoch 12/50
# 96/96 [==============================] - 5s 56ms/step - loss: 0.1594 - accuracy: 0.9462 - val_loss: 0.2570 - val_accuracy: 0.8953 - lr: 0.0010
# Epoch 13/50
# 96/96 [==============================] - 5s 57ms/step - loss: 0.1736 - accuracy: 0.9475 - val_loss: 0.3522 - val_accuracy: 0.8586 - lr: 0.0010
# Epoch 14/50
# 96/96 [==============================] - 6s 59ms/step - loss: 0.0959 - accuracy: 0.9646 - val_loss: 0.3622 - val_accuracy: 0.8848 - lr: 0.0010
# Epoch 15/50
# 96/96 [==============================] - 5s 56ms/step - loss: 0.0606 - accuracy: 0.9856 - val_loss: 0.2463 - val_accuracy: 0.9110 - lr: 2.0000e-04
# Epoch 16/50
# 96/96 [==============================] - 5s 56ms/step - loss: 0.0358 - accuracy: 0.9921 - val_loss: 0.2183 - val_accuracy: 0.9267 - lr: 2.0000e-04
# Epoch 17/50
# 96/96 [==============================] - 5s 56ms/step - loss: 0.0309 - accuracy: 0.9921 - val_loss: 0.2402 - val_accuracy: 0.9319 - lr: 2.0000e-04
# Epoch 18/50
# 96/96 [==============================] - 5s 56ms/step - loss: 0.0267 - accuracy: 0.9948 - val_loss: 0.2210 - val_accuracy: 0.9424 - lr: 2.0000e-04
# Epoch 19/50
# 96/96 [==============================] - 5s 56ms/step - loss: 0.0203 - accuracy: 0.9974 - val_loss: 0.2104 - val_accuracy: 0.9372 - lr: 1.0000e-04
# Epoch 20/50
# 96/96 [==============================] - 5s 57ms/step - loss: 0.0196 - accuracy: 0.9974 - val_loss: 0.2149 - val_accuracy: 0.9424 - lr: 1.0000e-04
# Epoch 21/50
# 96/96 [==============================] - 5s 57ms/step - loss: 0.0201 - accuracy: 0.9974 - val_loss: 0.2064 - val_accuracy: 0.9372 - lr: 1.0000e-04
# Epoch 22/50
# 96/96 [==============================] - 6s 58ms/step - loss: 0.0208 - accuracy: 0.9961 - val_loss: 0.2080 - val_accuracy: 0.9372 - lr: 1.0000e-04
# Epoch 23/50
# 96/96 [==============================] - 6s 57ms/step - loss: 0.0248 - accuracy: 0.9948 - val_loss: 0.2054 - val_accuracy: 0.9424 - lr: 1.0000e-04
# Epoch 24/50
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0128 - accuracy: 0.9987 - val_loss: 0.2055 - val_accuracy: 0.9319 - lr: 1.0000e-04
# Epoch 25/50
# 96/96 [==============================] - 6s 61ms/step - loss: 0.0136 - accuracy: 0.9987 - val_loss: 0.2117 - val_accuracy: 0.9424 - lr: 1.0000e-04
# Epoch 26/50
# 96/96 [==============================] - 6s 65ms/step - loss: 0.0180 - accuracy: 0.9961 - val_loss: 0.2060 - val_accuracy: 0.9319 - lr: 1.0000e-04
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 64, 64, 64)        5248
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 32)        51232
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 32)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 6, 6, 32)          9248
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 32)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 3, 3, 32)          0
#
#  flatten_1 (Flatten)         (None, 288)               0
#
#  dense_3 (Dense)             (None, 64)                18496
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dense_5 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 88,644
# Trainable params: 88,644
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_for_size.append((IMG_SIZE_EXPLORATION[2], train_with_image_resolution(IMG_SIZE_EXPLORATION[2])))
# Out:
# Epoch 1/50
# 96/96 [==============================] - 18s 181ms/step - loss: 1.3865 - accuracy: 0.2467 - val_loss: 1.3418 - val_accuracy: 0.3089 - lr: 0.0010
# Epoch 2/50
# 96/96 [==============================] - 18s 192ms/step - loss: 1.2862 - accuracy: 0.3688 - val_loss: 1.2175 - val_accuracy: 0.4293 - lr: 0.0010
# Epoch 3/50
# 96/96 [==============================] - 19s 198ms/step - loss: 1.0722 - accuracy: 0.5499 - val_loss: 0.9185 - val_accuracy: 0.7016 - lr: 0.0010
# Epoch 4/50
# 96/96 [==============================] - 20s 204ms/step - loss: 0.6726 - accuracy: 0.7717 - val_loss: 0.7802 - val_accuracy: 0.7068 - lr: 0.0010
# Epoch 5/50
# 96/96 [==============================] - 20s 207ms/step - loss: 0.5454 - accuracy: 0.8071 - val_loss: 0.4472 - val_accuracy: 0.8429 - lr: 0.0010
# Epoch 6/50
# 96/96 [==============================] - 21s 215ms/step - loss: 0.4379 - accuracy: 0.8543 - val_loss: 0.4852 - val_accuracy: 0.8325 - lr: 0.0010
# Epoch 7/50
# 96/96 [==============================] - 18s 189ms/step - loss: 0.3112 - accuracy: 0.8924 - val_loss: 0.3484 - val_accuracy: 0.8534 - lr: 0.0010
# Epoch 8/50
# 96/96 [==============================] - 19s 195ms/step - loss: 0.2608 - accuracy: 0.9081 - val_loss: 0.3341 - val_accuracy: 0.8796 - lr: 0.0010
# Epoch 9/50
# 96/96 [==============================] - 22s 230ms/step - loss: 0.1505 - accuracy: 0.9567 - val_loss: 0.2150 - val_accuracy: 0.9005 - lr: 0.0010
# Epoch 10/50
# 96/96 [==============================] - 23s 235ms/step - loss: 0.1644 - accuracy: 0.9436 - val_loss: 0.2468 - val_accuracy: 0.9215 - lr: 0.0010
# Epoch 11/50
# 96/96 [==============================] - 26s 270ms/step - loss: 0.0811 - accuracy: 0.9724 - val_loss: 0.2306 - val_accuracy: 0.9319 - lr: 0.0010
# Epoch 12/50
# 96/96 [==============================] - 20s 207ms/step - loss: 0.0398 - accuracy: 0.9882 - val_loss: 0.2195 - val_accuracy: 0.9424 - lr: 2.0000e-04
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 128, 128, 64)      5248
#
#  max_pooling2d_6 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        51232
#
#  max_pooling2d_7 (MaxPooling  (None, 11, 11, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 11, 11, 32)        9248
#
#  max_pooling2d_8 (MaxPooling  (None, 6, 6, 32)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 32)          0
#
#  flatten_2 (Flatten)         (None, 1152)              0
#
#  dense_6 (Dense)             (None, 64)                73792
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dense_8 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 143,940
# Trainable params: 143,940
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_for_size.append((IMG_SIZE_EXPLORATION[3], train_with_image_resolution(IMG_SIZE_EXPLORATION[3])))
# Out:
# Epoch 1/50
# 96/96 [==============================] - 91s 942ms/step - loss: 1.3970 - accuracy: 0.2848 - val_loss: 1.3432 - val_accuracy: 0.2827 - lr: 0.0010
# Epoch 2/50
# 96/96 [==============================] - 98s 1s/step - loss: 1.2984 - accuracy: 0.3556 - val_loss: 1.2223 - val_accuracy: 0.4031 - lr: 0.0010
# Epoch 3/50
# 96/96 [==============================] - 81s 841ms/step - loss: 1.0696 - accuracy: 0.5328 - val_loss: 0.9258 - val_accuracy: 0.6126 - lr: 0.0010
# Epoch 4/50
# 96/96 [==============================] - 89s 927ms/step - loss: 0.8956 - accuracy: 0.6404 - val_loss: 0.6431 - val_accuracy: 0.7225 - lr: 0.0010
# Epoch 5/50
# 96/96 [==============================] - 80s 829ms/step - loss: 0.6075 - accuracy: 0.7703 - val_loss: 0.4961 - val_accuracy: 0.7487 - lr: 0.0010
# Epoch 6/50
# 96/96 [==============================] - 85s 889ms/step - loss: 0.4742 - accuracy: 0.8268 - val_loss: 0.4865 - val_accuracy: 0.8325 - lr: 0.0010
# Epoch 7/50
# 96/96 [==============================] - 97s 1s/step - loss: 0.3343 - accuracy: 0.8898 - val_loss: 0.3488 - val_accuracy: 0.8743 - lr: 0.0010
# Epoch 8/50
# 96/96 [==============================] - 89s 923ms/step - loss: 0.2524 - accuracy: 0.9108 - val_loss: 0.2660 - val_accuracy: 0.9005 - lr: 0.0010
# Epoch 9/50
# 96/96 [==============================] - 89s 924ms/step - loss: 0.1656 - accuracy: 0.9436 - val_loss: 0.4639 - val_accuracy: 0.8953 - lr: 0.0010
# Epoch 10/50
# 96/96 [==============================] - 90s 938ms/step - loss: 0.0853 - accuracy: 0.9777 - val_loss: 0.1944 - val_accuracy: 0.9319 - lr: 0.0010
# Epoch 11/50
# 96/96 [==============================] - 82s 854ms/step - loss: 0.1150 - accuracy: 0.9593 - val_loss: 0.4739 - val_accuracy: 0.8691 - lr: 0.0010
# Epoch 12/50
# 96/96 [==============================] - 87s 905ms/step - loss: 0.0493 - accuracy: 0.9829 - val_loss: 0.1739 - val_accuracy: 0.9215 - lr: 0.0010
# Epoch 13/50
# 96/96 [==============================] - 90s 936ms/step - loss: 0.0693 - accuracy: 0.9764 - val_loss: 0.2604 - val_accuracy: 0.9267 - lr: 0.0010
# Epoch 14/50
# 96/96 [==============================] - 108s 1s/step - loss: 0.1786 - accuracy: 0.9475 - val_loss: 0.5530 - val_accuracy: 0.8848 - lr: 0.0010
# Epoch 15/50
# 96/96 [==============================] - 92s 954ms/step - loss: 0.0510 - accuracy: 0.9843 - val_loss: 0.2411 - val_accuracy: 0.9215 - lr: 2.0000e-04
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 256, 256, 64)      5248
#
#  max_pooling2d_9 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 64, 64, 32)        51232
#
#  max_pooling2d_10 (MaxPoolin  (None, 22, 22, 32)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 22, 22, 32)        9248
#
#  max_pooling2d_11 (MaxPoolin  (None, 11, 11, 32)       0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 11, 11, 32)        0
#
#  flatten_3 (Flatten)         (None, 3872)              0
#
#  dense_9 (Dense)             (None, 64)                247872
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  dense_11 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 318,020
# Trainable params: 318,020
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_for_size.append((IMG_SIZE_EXPLORATION[4], train_with_image_resolution(IMG_SIZE_EXPLORATION[4])))
# Out:
# Epoch 1/50
# 96/96 [==============================] - 125s 1s/step - loss: 1.3914 - accuracy: 0.2730 - val_loss: 1.4205 - val_accuracy: 0.1623 - lr: 0.0010
# Epoch 2/50
# 96/96 [==============================] - 124s 1s/step - loss: 1.3661 - accuracy: 0.3268 - val_loss: 1.2810 - val_accuracy: 0.4398 - lr: 0.0010
# Epoch 3/50
# 96/96 [==============================] - 129s 1s/step - loss: 1.2957 - accuracy: 0.4186 - val_loss: 1.2723 - val_accuracy: 0.4241 - lr: 0.0010
# Epoch 4/50
# 96/96 [==============================] - 136s 1s/step - loss: 1.0942 - accuracy: 0.5682 - val_loss: 0.8278 - val_accuracy: 0.6963 - lr: 0.0010
# Epoch 5/50
# 96/96 [==============================] - 136s 1s/step - loss: 0.8961 - accuracy: 0.6522 - val_loss: 0.6812 - val_accuracy: 0.7173 - lr: 0.0010
# Epoch 6/50
# 96/96 [==============================] - 138s 1s/step - loss: 0.7887 - accuracy: 0.7087 - val_loss: 0.6182 - val_accuracy: 0.7644 - lr: 0.0010
# Epoch 7/50
# 96/96 [==============================] - 143s 1s/step - loss: 0.5724 - accuracy: 0.8005 - val_loss: 0.4512 - val_accuracy: 0.8010 - lr: 0.0010
# Epoch 8/50
# 96/96 [==============================] - 157s 2s/step - loss: 0.4652 - accuracy: 0.8360 - val_loss: 0.2849 - val_accuracy: 0.8848 - lr: 0.0010
# Epoch 9/50
# 96/96 [==============================] - 149s 2s/step - loss: 0.3296 - accuracy: 0.8871 - val_loss: 0.5602 - val_accuracy: 0.8168 - lr: 0.0010
# Epoch 10/50
# 96/96 [==============================] - 147s 2s/step - loss: 0.2073 - accuracy: 0.9318 - val_loss: 0.2174 - val_accuracy: 0.9319 - lr: 0.0010
# Epoch 11/50
# 96/96 [==============================] - 136s 1s/step - loss: 0.1005 - accuracy: 0.9738 - val_loss: 0.1719 - val_accuracy: 0.9372 - lr: 0.0010
# Epoch 12/50
# 96/96 [==============================] - 149s 2s/step - loss: 0.0628 - accuracy: 0.9816 - val_loss: 0.2252 - val_accuracy: 0.9267 - lr: 0.0010
# Epoch 13/50
# 96/96 [==============================] - 146s 2s/step - loss: 0.1808 - accuracy: 0.9370 - val_loss: 0.2199 - val_accuracy: 0.9372 - lr: 0.0010
# Epoch 14/50
# 96/96 [==============================] - 151s 2s/step - loss: 0.0559 - accuracy: 0.9829 - val_loss: 0.1646 - val_accuracy: 0.9424 - lr: 2.0000e-04
# Epoch 15/50
# 96/96 [==============================] - 152s 2s/step - loss: 0.0259 - accuracy: 0.9961 - val_loss: 0.1721 - val_accuracy: 0.9529 - lr: 2.0000e-04
# Epoch 16/50
# 96/96 [==============================] - 154s 2s/step - loss: 0.0195 - accuracy: 0.9948 - val_loss: 0.1683 - val_accuracy: 0.9529 - lr: 2.0000e-04
# Epoch 17/50
# 96/96 [==============================] - 140s 1s/step - loss: 0.0162 - accuracy: 0.9974 - val_loss: 0.1712 - val_accuracy: 0.9529 - lr: 1.0000e-04
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 320, 320, 64)      5248
#
#  max_pooling2d_12 (MaxPoolin  (None, 80, 80, 64)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 80, 80, 32)        51232
#
#  max_pooling2d_13 (MaxPoolin  (None, 27, 27, 32)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 27, 27, 32)        9248
#
#  max_pooling2d_14 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 14, 14, 32)        0
#
#  flatten_4 (Flatten)         (None, 6272)              0
#
#  dense_12 (Dense)            (None, 64)                401472
#
#  dense_13 (Dense)            (None, 64)                4160
#
#  dense_14 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 471,620
# Trainable params: 471,620
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_for_size.append((IMG_SIZE_EXPLORATION[5], train_with_image_resolution(IMG_SIZE_EXPLORATION[5])))

# %%
history_for_size.append((IMG_SIZE_EXPLORATION[6], train_with_image_resolution(IMG_SIZE_EXPLORATION[6])))

# %%
history_for_size.append((IMG_SIZE_EXPLORATION[7], train_with_image_resolution(IMG_SIZE_EXPLORATION[7])))

# %%
history_for_size
# Out:
# [(32, <keras.callbacks.History at 0x1f76eb68a00>),
#  (64, <keras.callbacks.History at 0x1f77172cd00>),
#  (128, <keras.callbacks.History at 0x1f7719bbdc0>),
#  (256, <keras.callbacks.History at 0x1f7716bd5e0>),
#  (320, <keras.callbacks.History at 0x1f7716b6220>)]

# %%
for history in history_for_size:
    size = history[0]
    hist = history[1]

    fig = plt.figure(figsize=(15, 7))
    ax = plt.gca()
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Accuracy (Line), Loss (Dashes)')
    ax.axhline(1, color='gray')
    
    loss = hist.history['loss']
    val_loss = hist.history['val_loss']
    accuracy = hist.history['accuracy']
    val_accuracy = hist.history['val_accuracy']

    plt.plot(accuracy, color='blue')
    plt.plot(val_accuracy, color='orange')
    plt.plot(loss, '--', color='blue', alpha=0.5)
    plt.plot(val_loss, '--', color='orange', alpha=0.5)

# %% [markdown]
# ## Visualize results
